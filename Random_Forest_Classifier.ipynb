# %% [markdown]
# <a href="https://colab.research.google.com/github/rupeshrgarje/New-Repository/blob/main/Random_Forest_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the data
df = pd.read_csv('pima-indians-diabetes.csv',
                 names = ['pregnancies', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label'])
df.head()
# Out:
#    pregnancies  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0            6      148  72    35        0  33.6     0.627   50      1
# 1            1       85  66    29        0  26.6     0.351   31      0
# 2            8      183  64     0        0  23.3     0.672   32      1
# 3            1       89  66    23       94  28.1     0.167   21      0
# 4            0      137  40    35      168  43.1     2.288   33      1

# %%
# Seperating the input and output data
X = df.drop('label', axis = 1)
y = df['label']

# %%
# Performing train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
# Creating a Random Forest Classifier
clf = RandomForestClassifier(n_estimators = 100)

# Fitting the data
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Taking the predictions from the model
y_pred = clf.predict(X_test)
y_train_pred = clf.predict(X_train)

# %%
# Model Evaluation
print('Training Accuracy: ', np.round(metrics.accuracy_score(y_train, y_train_pred), 2))
print('Training Precision: ', np.round(metrics.precision_score(y_train, y_train_pred), 2))
print('Training Recall: ', np.round(metrics.recall_score(y_train, y_train_pred), 2))
print('Training F1 Score: ', np.round(metrics.f1_score(y_train, y_train_pred), 2))

print('\nTesting Accuracy: ', np.round(metrics.accuracy_score(y_test, y_pred), 2))
print('Testing Precision: ', np.round(metrics.precision_score(y_test, y_pred), 2))
print('Testing Recall: ', np.round(metrics.recall_score(y_test, y_pred), 2))
print('Testing F1 Score: ', np.round(metrics.f1_score(y_test, y_pred), 2))
# Out:
# Training Accuracy:  1.0
# Training Precision:  1.0
# Training Recall:  1.0
# Training F1 Score:  1.0
#
# Testing Accuracy:  0.77
# Testing Precision:  0.69
# Testing Recall:  0.61
# Testing F1 Score:  0.65

# %%
'''
Comment -> The above model is clearly overfitted
Homework -> Please perform hyper-parameter optimization
using GridSearchCV() and RandomizedSearchCV()
'''

# %%
# Confusion Matrix
data = pd.crosstab(y_test, y_pred)
plt.figure(figsize = (5, 3))
sns.heatmap(data, annot = True)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Generating the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83       100
#            1       0.69      0.61      0.65        54
#
#     accuracy                           0.77       154
#    macro avg       0.74      0.73      0.74       154
# weighted avg       0.76      0.77      0.76       154
